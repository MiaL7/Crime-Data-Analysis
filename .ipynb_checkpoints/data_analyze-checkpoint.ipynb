# %%
import pandas as pd

# %%
df = pd.read_pickle('cleaned_df.pkl')
df.head()
# Out:
#                 DR_NO  TIME OCC  AREA  AREA NAME  Rpt Dist No  Crm Cd  \
# DATE OCC
# 2020-01-01  200300501       930     3  Southwest          392     624
# 2020-01-01  200113272         1     1    Central          152     820
# 2020-01-01  200807173      1900     8    West LA          811     341
# 2020-01-01  201404035       730    14    Pacific         1406     626
# 2020-01-01  211905178      1159    19    Mission         1977     354
#
#                                                   Crm Cd Desc  Vict Age  \
# DATE OCC
# 2020-01-01                           BATTERY - SIMPLE ASSAULT        29
# 2020-01-01                                    ORAL COPULATION        53
# 2020-01-01  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        67
# 2020-01-01                  INTIMATE PARTNER - SIMPLE ASSAULT         0
# 2020-01-01                                  THEFT OF IDENTITY        36
#
#            Vict Sex Vict Descent  Premis Cd  \
# DATE OCC
# ...
